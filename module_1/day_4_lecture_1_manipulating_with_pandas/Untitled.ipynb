# %%
# !pwd
# !ls -al
# Out:
# /Users/flatiron/Desktop/data_sc_fs/dc_ds_04_22_19/module_1/day_4_lecture_1_manipulating_with_pandas
# total 96
# drwxr-xr-x  10 flatiron  staff    320 Apr 25 10:15 .
# drwxr-xr-x  14 flatiron  staff    448 Apr 25 09:56 ..
# drwxr-xr-x   4 flatiron  staff    128 Apr 25 10:15 .ipynb_checkpoints
# -rw-r--r--   1 flatiron  staff     72 Apr 25 10:15 Untitled.ipynb
# -rw-r--r--   1 flatiron  staff     95 Apr 25 09:56 ds_chars.csv
# -rw-r--r--   1 flatiron  staff  11328 Apr 25 09:56 heart.csv
# drwxr-xr-x   4 flatiron  staff    128 Apr 25 09:56 images
# -rw-r--r--   1 flatiron  staff  16603 Apr 25 10:05 manipulating_data_with_pandas.ipynb
# -rw-r--r--   1 flatiron  staff   3297 Apr 25 09:56 pre_process_animal_shelter_data.py
# -rw-r--r--   1 flatiron  staff    130 Apr 25 09:56 states.csv

# %%
import pandas as pd
uci = pd.read_csv('heart.csv')

# %%
uci.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
uci.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
# age         303 non-null int64
# sex         303 non-null int64
# cp          303 non-null int64
# trestbps    303 non-null int64
# chol        303 non-null int64
# fbs         303 non-null int64
# restecg     303 non-null int64
# thalach     303 non-null int64
# exang       303 non-null int64
# oldpeak     303 non-null float64
# slope       303 non-null int64
# ca          303 non-null int64
# thal        303 non-null int64
# target      303 non-null int64
# dtypes: float64(1), int64(13)
# memory usage: 33.2 KB

# %%
uci.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
uci.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
uci.mean()
# Out:
# age          54.366337
# sex           0.683168
# cp            0.966997
# trestbps    131.623762
# chol        246.264026
# fbs           0.148515
# restecg       0.528053
# thalach     149.646865
# exang         0.326733
# oldpeak       1.039604
# slope         1.399340
# ca            0.729373
# thal          2.313531
# target        0.544554
# dtype: float64

# %%
uci.ca.mean()
# Out:
# 0.7293729372937293

# %%
uci['age'].value_counts()
# Out:
# 58    19
# 57    17
# 54    16
# 59    14
# 52    13
# 51    12
# 62    11
# 44    11
# 60    11
# 56    11
# 64    10
# 41    10
# 63     9
# 67     9
# 55     8
# 45     8
# 42     8
# 53     8
# 61     8
# 65     8
# 43     8
# 66     7
# 50     7
# 48     7
# 46     7
# 49     5
# 47     5
# 39     4
# 35     4
# 68     4
# 70     4
# 40     3
# 71     3
# 69     3
# 38     3
# 34     2
# 37     2
# 77     1
# 76     1
# 74     1
# 29     1
# Name: age, dtype: int64
