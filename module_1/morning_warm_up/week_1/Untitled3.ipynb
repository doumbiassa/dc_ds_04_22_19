# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.linspace(0, 10,60)

# %%
y = np.sin(x)

# %%
plt.scatter(x, y, label="Function: Sin" )
plt.title('Scatter plot')
plt.legend()
plt.show()
