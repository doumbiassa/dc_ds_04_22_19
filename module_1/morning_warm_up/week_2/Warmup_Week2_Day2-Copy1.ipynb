# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('suicide_rates.csv')

# %%
df.head()
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1987    male  15-24 years           21      312900
# 1  Albania  1987    male  35-54 years           16      308000
# 2  Albania  1987  female  15-24 years           14      289700
# 3  Albania  1987    male    75+ years            1       21800
# 4  Albania  1987    male  25-34 years            9      274300
#
#    suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 0               6.71  Albania1987           NaN      2,156,624,900
# 1               5.19  Albania1987           NaN      2,156,624,900
# 2               4.83  Albania1987           NaN      2,156,624,900
# 3               4.59  Albania1987           NaN      2,156,624,900
# 4               3.28  Albania1987           NaN      2,156,624,900
#
#    gdp_per_capita ($)       generation
# 0                 796     Generation X
# 1                 796           Silent
# 2                 796     Generation X
# ...

# %%
rows_data = df[df['country'].apply(lambda x: x.startswith('U'))]

# %%
rows_data.tail(50)
# Out:
#           country  year     sex          age  suicides_no  population  \
# 27770  Uzbekistan  2010  female  55-74 years           16     1161422
# 27771  Uzbekistan  2010  female   5-14 years           30     2627344
# 27772  Uzbekistan  2011    male  35-54 years          457     3204569
# 27773  Uzbekistan  2011    male  25-34 years          271     2457050
# 27774  Uzbekistan  2011    male  15-24 years          264     3211080
# 27775  Uzbekistan  2011  female  15-24 years          248     3092119
# 27776  Uzbekistan  2011    male  55-74 years           76     1086405
# 27777  Uzbekistan  2011  female  25-34 years          139     2469295
# 27778  Uzbekistan  2011    male    75+ years           10      204956
# 27779  Uzbekistan  2011  female  35-54 years           78     3404363
# 27780  Uzbekistan  2011    male   5-14 years           45     2710780
# 27781  Uzbekistan  2011  female  55-74 years           19     1218296
# ...

# %%
list(rows_data['country'].unique())
# Out:
# ['Ukraine',
#  'United Arab Emirates',
#  'United Kingdom',
#  'United States',
#  'Uruguay',
#  'Uzbekistan']

# %%
rows_data['country'].unique()
# Out:
# array(['Ukraine', 'United Arab Emirates', 'United Kingdom',
#        'United States', 'Uruguay', 'Uzbekistan'], dtype=object)

# %%
rows_data[rows_data.iloc[:,0] == 'United States']
# Out:
#              country  year     sex          age  suicides_no  population  \
# 26848  United States  1985    male    75+ years         2177     4064000
# 26849  United States  1985    male  55-74 years         5302    17971000
# 26850  United States  1985    male  25-34 years         5134    20986000
# 26851  United States  1985    male  35-54 years         6053    26589000
# 26852  United States  1985    male  15-24 years         4267    19962000
# 26853  United States  1985  female  35-54 years         2105    27763000
# 26854  United States  1985  female  55-74 years         1568    21366000
# 26855  United States  1985  female    75+ years          466     7469000
# 26856  United States  1985  female  25-34 years         1242    21041000
# 26857  United States  1985  female  15-24 years          854    19589000
# 26858  United States  1985    male   5-14 years          205    17370000
# 26859  United States  1985  female   5-14 years           73    16553000
# ...

# %%
rows_data.index
# Out:
# Int64Index([26068, 26069, 26070, 26071, 26072, 26073, 26074, 26075, 26076,
#             26077,
#             ...
#             27810, 27811, 27812, 27813, 27814, 27815, 27816, 27817, 27818,
#             27819],
#            dtype='int64', length=1752)

# %%
rows_data.groupby('age')['suicides_no'].sum()
# Out:
# age
# 15-24 years    195656
# 25-34 years    268759
# 35-54 years    574686
# 5-14 years      12596
# 55-74 years    352590
# 75+ years      135044
# Name: suicides_no, dtype: int64

# %%
rows_data['age_category'] = rows_data['age'].astype('category')
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
list_age_category = list(set(rows_data['age_category']))

# %%
for i, v in enumerate(list_age_category):
    print(i,v)
# Out:
# 0 25-34 years
# 1 15-24 years
# 2 55-74 years
# 3 75+ years
# 4 5-14 years
# 5 35-54 years

# %%
sorted_age_category=[]
sorted_age_category.append(list_age_category[4])
sorted_age_category.append(list_age_category[1])
sorted_age_category.append(list_age_category[0])
sorted_age_category.append(list_age_category[5])
sorted_age_category.append(list_age_category[2])
sorted_age_category.append(list_age_category[3])
sorted_age_category
# Out:
# ['5-14 years',
#  '15-24 years',
#  '25-34 years',
#  '35-54 years',
#  '55-74 years',
#  '75+ years']

# %%
rows_data['sorted_age_category'] = rows_data['age_category'].cat.reorder_categories(sorted_age_category)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
rows_data.head()
# Out:
#        country  year     sex          age  suicides_no  population  \
# 26068  Ukraine  1987    male    75+ years          506      654800
# 26069  Ukraine  1987    male  55-74 years         1934     3652600
# 26070  Ukraine  1987    male  35-54 years         3093     6206800
# 26071  Ukraine  1987    male  25-34 years         1383     3890300
# 26072  Ukraine  1987  female    75+ years          486     1816100
#
#        suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 26068              77.28  Ukraine1987           NaN     64,087,694,038
# 26069              52.95  Ukraine1987           NaN     64,087,694,038
# 26070              49.83  Ukraine1987           NaN     64,087,694,038
# 26071              35.55  Ukraine1987           NaN     64,087,694,038
# 26072              26.76  Ukraine1987           NaN     64,087,694,038
#
#        gdp_per_capita ($)       generation age_category sorted_age_category
# ...

# %%
sorted_age_category
# Out:
# ['5-14 years',
#  '15-24 years',
#  '25-34 years',
#  '35-54 years',
#  '55-74 years',
#  '75+ years']

# %%
print(reorder_data)
# Out:
# <bound method PandasDelegate._add_delegate_accessors.<locals>._create_delegator_method.<locals>.f of <pandas.core.arrays.categorical.CategoricalAccessor object at 0x122c46eb8>>

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
sns.pairplot(rows_data)
# Out:
# /anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
