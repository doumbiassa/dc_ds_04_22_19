# %% [markdown]
# # APIs and Python

# %% [markdown]
# ## The Many Use Cases for APIs
# APIs can actually be used for many things - not just for retrieving information. Twilio has an API that allows you to write a script to call their API to send text messages to people. GitHub has an API for creating new repositories. Many services have an API allowing a computer to automate a task that a person might otherwise have to do through a website - whether uploading a photo to Flickr, searching for a company name in a state database or getting a list of garbage collection times for a municipality.

# %% [markdown]
# ### _Learning Goals:_<br/>
#   - Identify and discuss APIs
#   - Discuss and explain different request (GET, POST, PUT, DELETE) and CRUD operations
#   - Explore the attributes of a response object
#   - Check the status of a request and interpret status codes
#   - Access data from an API using the requests library
#   - Create a pandas dataframe from the data returned from an API and visualize the data
#   - If time, target an API of their own!!!

# %% [markdown]
# ## Limitations of APIs
# When working with APIs, there are some limitations you have to be aware of - especially relating to scope and scale.

# %% [markdown]
# * **Scope** - Just because a company has an API and has information, it doesn't mean you can get all of the information through their API.

# %% [markdown]
# * **Scale** - Some APIs are provided for free as a public service. Others you have to pay for, or allow you to perform activities (like sending a text message) that you pay for. Make sure that you know what the rate limits are and that your use case isn't going to need more API calls than you will be able to make.

# %% [markdown]
# Let's take a look at the `requests` library and it's uses.

# %% [markdown]
# ### "Requests is the only Non-GMO HTTP library for Python, safe for human consumption."
#
# ![img-req](requests-pic.jpeg)
#
# Straight from the `requests` [documentation](https://pypi.org/project/requests/)

# %% [markdown]
# ![nongmao](requests_med.png)
#
# "Requests allows you to send organic, grass-fed HTTP/1.1 requests, without the need for manual labor. "<br>
# [More requests documentation](https://2.python-requests.org//en/v0.10.6/api/)

# %% [markdown]
# ### Let's get started!

# %%
import requests

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /anaconda3/lib/python3.7/site-packages (2.21.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /anaconda3/lib/python3.7/site-packages (from requests) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /anaconda3/lib/python3.7/site-packages (from requests) (1.24.1)
# Requirement already satisfied: idna<2.9,>=2.5 in /anaconda3/lib/python3.7/site-packages (from requests) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda3/lib/python3.7/site-packages (from requests) (2019.3.9)

# %% [markdown]
# ### Types of requests
#
# We will mostly use GET, but there are other options
#
# Let's say you are looking at an API for a car rental company like Hertz, or maybe even Zipcar.
#
# The following different requests will generate these different responses.
#
# |Request        | Result        |
# |-------------|-------------|
# |GET /stores/   | User sees the list of stores|
# |GET /rentals/  | User sees the history of car rentals|
# |POST /rentals/ | User rents a car|
# |PUT /rentals/{id}/| User changes destination store|
# |DELETE /rentals/{id}/| User cancels the active car rental|

# %%
rental_json = [{
    "id": 1,
    "name": "John St",
    "location": [29, 95],
    "available_cars_quantity": 10
},
{
    "id": 2,
    "name": "Scott St.",
    "location": [29.5, 95.7],
    "available_cars_quantity": 2
}]

# %%
#create a post request from https://httpbin.org/post and view it in json format

r = requests.post() #put url and data = {'key':'value'} format here in the bananas!
r.json()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-41d0f0202661> in <module>
#       1 #create a post request from https://httpbin.org/post and view it in json format
#       2
# ----> 3 r = requests.post() #put url and data = {'key':'value'} format here in the bananas!
#       4 r.json()
#
# TypeError: post() missing 1 required positional argument: 'url'

# %% [markdown]
# ### Request Class and Attributes

# %%
#create a GET request from https://api.github.com/events and view it in json format

r = requests.get('https://api.github.com/events') #put url here in the bananas!
type(r)

# %% [markdown]
# Let's check the `attributes` of a `Response` object. <br>
# https://2.python-requests.org//en/v0.10.6/api/
#
# Some key attributes:
#
# - url
# - text
# - status_code
# - headers
# - error

# %% [markdown]
# ### Checking out the status of your request

# %%
#get the status of your post request
r.status_code

# %% [markdown]
# #### Types of status codes
# 1xx - Informational responses
#
# 2xx - Success
# - 200 OK
# - 201 Created
# - 204 No Content
#
# 3xx - Redirection
#
# - 301 Moved Permanently (permanent URL redirection)
# - 304 Not Modified (A conditional GET or HEAD request has been received and would have resulted in a 200 OK response if it were not for the fact that the condition evaluated to false.)

# %% [markdown]
# 4xx - Client errors
#
# - 400 Bad Request
# - 401 Unauthorized
# - 403 Forbidden
# - 404 Not Found
#
# 5xx - Server errors
#
# - 500 Internal Server Error

# %% [markdown]
# https://http.cat

# %%
#get status code for a "broken" link

r = requests.get('https://api.github.com/fake-ending')
r.status_code
# Out:
# 404

# %% [markdown]
# Can also explictly ask for the returned format to be json as a method.

# %%
r.json()
# Out:
# {'message': 'Not Found',
#  'documentation_url': 'https://developer.github.com/v3'}

# %% [markdown]
# #### A note on errors and exceptions with the Requests library
#
# There are a number of exceptions and error codes you need to be familiar with when using the Requests library in Python.
#
# - The Requests library will raise a ConnectionError exception if there is a network problem like a DNS failure, or refused connection.
# - These are rare, but with invalid HTTP responses, Requests will also raise an HTTPError exception.
# - A Timeout exception will be raised if a request times out.
# - If and when a request exceeds the preconfigured number of maximum redirections, then a TooManyRedirects exception will be raised

# %% [markdown]
# Now that we know a bit more about APIs and how to interact with them in python, let's actually investigate an API from scratch.
#
# To start, go over to the API documentation at:
#
# https://dev.socrata.com/foundry/data.cityofnewyork.us/fhrw-4uyv
#
#
# <img src="311_api_docs.png">

# %% [markdown]
# ## Make an initial API call to retrieve 311 complaints from a neighborhood or zip code of your choice in New York City.

# %% [markdown]
# ### Using Requests

# %%
import requests
import pandas as pd

zip_code = '11004'

# can't figure out date ranges at the moment...
start_date = '2018-01-01T12:00:00'
end_date = '2018-02-01T12:00:00'

# create pull request based on parameters
# https://data.cityofnewyork.us/Social-Services/311-Service-Requests-from-2010-to-Present/erm2-nwe9 click API

url = "https://opendata.arcgis.com/datasets/89bfd2aed9a142249225a638448a5276_29.geojson"

# do the pull
response = requests.get(url)
response.json()
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {'OBJECTID': 1001,
#     'ID': '4D35075',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC4D',
#     'LATITUDE': 38.933,
#     'LONGITUDE': -77.003,
#     'DATETIME': '2014-05-03T01:55:35.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-77.0030000001, 38.9329999998]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1002,
#     'ID': '4D35076',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC4D',
#     'LATITUDE': 38.933,
#     'LONGITUDE': -77.003,
#     'DATETIME': '2014-05-03T01:55:50.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-77.0030000001, 38.9329999998]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1003,
#     'ID': '4D35077',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC4D',
#     'LATITUDE': 38.933,
#     'LONGITUDE': -77.003,
#     'DATETIME': '2014-05-03T01:57:17.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-77.0030000001, 38.9329999998]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1004,
#     'ID': '4D35078',
#     'TYPE': 'Gunshot_or_Firecracker',
#     'SOURCE': 'WashingtonDC4D',
#     'LATITUDE': 38.933,
#     'LONGITUDE': -77.003,
#     'DATETIME': '2014-05-03T01:58:23.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-77.0030000001, 38.9329999998]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1005,
#     'ID': '1D57488',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC1D',
#     'LATITUDE': 38.875,
#     'LONGITUDE': -77.012,
#     'DATETIME': '2014-05-03T03:44:42.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-77.0119999995, 38.8750000001]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1006,
#     'ID': '7D123806',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.833,
#     'LONGITUDE': -77.006,
#     'DATETIME': '2014-05-03T03:54:36.000Z'},
#    'geometry': {'type': 'Point', 'coordinates': [-77.006, 38.8329999997]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1007,
#     'ID': '7D123807',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.857,
#     'LONGITUDE': -76.97,
#     'DATETIME': '2014-05-03T04:01:34.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9699999999, 38.8569999996]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1008,
#     'ID': '6D104881',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.898,
#     'LONGITUDE': -76.906,
#     'DATETIME': '2014-05-03T05:31:44.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9059999998, 38.8980000002]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1009,
#     'ID': '7D123810',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.847,
#     'LONGITUDE': -76.955,
#     'DATETIME': '2014-05-03T05:41:09.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9549999999, 38.8470000001]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1010,
#     'ID': '7D123811',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.848,
#     'LONGITUDE': -76.96300000000001,
#     'DATETIME': '2014-05-03T05:41:29.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9630000001, 38.8480000001]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1011,
#     'ID': '5D40622',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC5D',
#     'LATITUDE': 38.922000000000004,
#     'LONGITUDE': -77.001,
#     'DATETIME': '2014-05-03T05:43:02.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-77.0010000005, 38.9219999997]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1012,
#     'ID': '3D43791',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC3D',
#     'LATITUDE': 38.922000000000004,
#     'LONGITUDE': -77.00200000000001,
#     'DATETIME': '2014-05-03T05:43:02.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-77.0020000006, 38.9220000003]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1013,
#     'ID': '6D104882',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.876000000000005,
#     'LONGITUDE': -76.932,
#     'DATETIME': '2014-05-03T06:05:20.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9320000002, 38.8759999996]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1014,
#     'ID': '7D123812',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.849000000000004,
#     'LONGITUDE': -76.97500000000001,
#     'DATETIME': '2014-05-03T06:08:59.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9750000002, 38.8490000001]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1078,
#     'ID': '7D124306',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.834,
#     'LONGITUDE': -76.98700000000001,
#     'DATETIME': '2014-05-08T02:59:51.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9869999995, 38.8340000001]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1079,
#     'ID': '6D105071',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.87,
#     'LONGITUDE': -76.925,
#     'DATETIME': '2014-05-08T04:11:10.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9250000004, 38.8700000001]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1080,
#     'ID': '5D40680',
#     'TYPE': 'Gunshot_or_Firecracker',
#     'SOURCE': 'WashingtonDC5D',
#     'LATITUDE': 38.914,
#     'LONGITUDE': -77.016,
#     'DATETIME': '2014-05-08T07:26:37.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-77.0159999995, 38.9139999996]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1081,
#     'ID': '4D35120',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC4D',
#     'LATITUDE': 38.949000000000005,
#     'LONGITUDE': -77.024,
#     'DATETIME': '2014-05-08T08:49:51.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-77.0240000004, 38.9490000003]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1082,
#     'ID': '3D43826',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC3D',
#     'LATITUDE': 38.917,
#     'LONGITUDE': -77.02300000000001,
#     'DATETIME': '2014-05-08T11:48:28.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-77.0230000003, 38.9169999996]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1083,
#     'ID': '6D105081',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.887,
#     'LONGITUDE': -76.95,
#     'DATETIME': '2014-05-08T20:20:03.000Z'},
#    'geometry': {'type': 'Point', 'coordinates': [-76.95, 38.8870000002]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1084,
#     'ID': '6D105086',
#     'TYPE': 'Gunshot_or_Firecracker',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.897,
#     'LONGITUDE': -76.949,
#     'DATETIME': '2014-05-08T23:40:43.000Z'},
#    'geometry': {'type': 'Point', 'coordinates': [-76.949, 38.8970000004]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1085,
#     'ID': '7D124360',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.845,
#     'LONGITUDE': -76.973,
#     'DATETIME': '2014-05-09T00:47:54.000Z'},
#    'geometry': {'type': 'Point', 'coordinates': [-76.9729999995, 38.845]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1086,
#     'ID': '5D40688',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC5D',
#     'LATITUDE': 38.925000000000004,
#     'LONGITUDE': -77.00200000000001,
#     'DATETIME': '2014-05-09T02:10:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-77.0019999994, 38.9250000002]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1087,
#     'ID': '6D105098',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.885000000000005,
#     'LONGITUDE': -76.955,
#     'DATETIME': '2014-05-09T02:42:59.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9550000002, 38.8850000004]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1088,
#     'ID': '1D57567',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC1D',
#     'LATITUDE': 38.87,
#     'LONGITUDE': -77.009,
#     'DATETIME': '2014-05-09T04:58:02.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-77.0089999996, 38.8699999996]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1089,
#     'ID': '7D124383',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.835,
#     'LONGITUDE': -76.992,
#     'DATETIME': '2014-05-09T06:44:55.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9920000002, 38.8349999997]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1090,
#     'ID': '7D124384',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.835,
#     'LONGITUDE': -76.991,
#     'DATETIME': '2014-05-09T06:45:15.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9910000001, 38.8349999999]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1091,
#     'ID': '6D105126',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.892,
#     'LONGITUDE': -76.952,
#     'DATETIME': '2014-05-10T00:35:03.000Z'},
#    'geometry': {'type': 'Point', 'coordinates': [-76.9519999998, 38.892]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1092,
#     'ID': '7D124448',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.832,
#     'LONGITUDE': -77.004,
#     'DATETIME': '2014-05-10T02:27:58.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-77.0039999997, 38.8320000001]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1093,
#     'ID': '5D40692',
#     'TYPE': 'Gunshot_or_Firecracker',
#     'SOURCE': 'WashingtonDC5D',
#     'LATITUDE': 38.904,
#     'LONGITUDE': -76.989,
#     'DATETIME': '2014-05-10T03:33:14.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9890000001, 38.9039999997]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1094,
#     'ID': '1D57572',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC1D',
#     'LATITUDE': 38.901,
#     'LONGITUDE': -76.988,
#     'DATETIME': '2014-05-10T03:38:16.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9879999995, 38.9009999997]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1095,
#     'ID': '6D105139',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.891000000000005,
#     'LONGITUDE': -76.912,
#     'DATETIME': '2014-05-10T03:48:21.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9120000001, 38.8909999998]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1096,
#     'ID': '1D57573',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC1D',
#     'LATITUDE': 38.901,
#     'LONGITUDE': -76.988,
#     'DATETIME': '2014-05-10T03:52:35.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9879999995, 38.9009999997]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1097,
#     'ID': '6D105140',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.879000000000005,
#     'LONGITUDE': -76.93,
#     'DATETIME': '2014-05-10T04:25:13.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9299999997, 38.8790000002]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1098,
#     'ID': '6D105141',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.88,
#     'LONGITUDE': -76.931,
#     'DATETIME': '2014-05-10T04:25:23.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9310000001, 38.8800000001]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1099,
#     'ID': '6D105144',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.895,
#     'LONGITUDE': -76.956,
#     'DATETIME': '2014-05-10T06:13:43.000Z'},
#    'geometry': {'type': 'Point', 'coordinates': [-76.9560000002, 38.895]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1100,
#     'ID': '6D105145',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.9,
#     'LONGITUDE': -76.943,
#     'DATETIME': '2014-05-10T06:52:45.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9429999994, 38.8999999996]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1101,
#     'ID': '7D124455',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.845,
#     'LONGITUDE': -76.986,
#     'DATETIME': '2014-05-10T07:50:15.000Z'},
#    'geometry': {'type': 'Point', 'coordinates': [-76.9860000003, 38.845]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1102,
#     'ID': '1D57574',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC1D',
#     'LATITUDE': 38.895,
#     'LONGITUDE': -76.979,
#     'DATETIME': '2014-05-10T20:46:20.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9790000003, 38.8949999999]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1103,
#     'ID': '1D57576',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC1D',
#     'LATITUDE': 38.901,
#     'LONGITUDE': -76.98400000000001,
#     'DATETIME': '2014-05-10T23:20:26.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9839999997, 38.9009999997]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1104,
#     'ID': '6D105201',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.897,
#     'LONGITUDE': -76.94,
#     'DATETIME': '2014-05-11T03:14:32.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9400000002, 38.8970000001]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1105,
#     'ID': '6D105203',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.894,
#     'LONGITUDE': -76.937,
#     'DATETIME': '2014-05-11T04:13:27.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9369999995, 38.8940000003]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1106,
#     'ID': '7D124796',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.861000000000004,
#     'LONGITUDE': -76.986,
#     'DATETIME': '2014-05-11T05:22:19.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9859999998, 38.8609999998]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1107,
#     'ID': '3D43835',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC3D',
#     'LATITUDE': 38.913000000000004,
#     'LONGITUDE': -77.018,
#     'DATETIME': '2014-05-11T05:47:39.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-77.0180000003, 38.9130000001]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1108,
#     'ID': '5D40709',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC5D',
#     'LATITUDE': 38.913000000000004,
#     'LONGITUDE': -77.02,
#     'DATETIME': '2014-05-11T05:47:43.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-77.0200000006, 38.9130000001]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1109,
#     'ID': '5D40710',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC5D',
#     'LATITUDE': 38.918,
#     'LONGITUDE': -77.01,
#     'DATETIME': '2014-05-11T06:24:42.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-77.0100000005, 38.9180000001]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1110,
#     'ID': '5D40711',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC5D',
#     'LATITUDE': 38.918,
#     'LONGITUDE': -77.01100000000001,
#     'DATETIME': '2014-05-11T06:27:32.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-77.0109999998, 38.9180000003]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1111,
#     'ID': '7D124797',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.857,
#     'LONGITUDE': -76.974,
#     'DATETIME': '2014-05-11T06:54:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9739999996, 38.8570000003]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1112,
#     'ID': '7D124798',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.832,
#     'LONGITUDE': -76.988,
#     'DATETIME': '2014-05-11T07:03:11.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9880000004, 38.8319999997]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1113,
#     'ID': '5D40714',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC5D',
#     'LATITUDE': 38.911,
#     'LONGITUDE': -76.99900000000001,
#     'DATETIME': '2014-05-11T07:09:55.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9989999998, 38.9109999996]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1114,
#     'ID': '5D40715',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC5D',
#     'LATITUDE': 38.911,
#     'LONGITUDE': -76.998,
#     'DATETIME': '2014-05-11T07:10:03.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9979999995, 38.9110000003]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1115,
#     'ID': '5D40716',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC5D',
#     'LATITUDE': 38.911,
#     'LONGITUDE': -76.997,
#     'DATETIME': '2014-05-11T07:10:04.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9970000003, 38.9109999996]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1116,
#     'ID': '7D124800',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.831,
#     'LONGITUDE': -76.99300000000001,
#     'DATETIME': '2014-05-11T07:26:13.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9929999997, 38.8310000004]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1117,
#     'ID': '5D40754',
#     'TYPE': 'Gunshot_or_Firecracker',
#     'SOURCE': 'WashingtonDC5D',
#     'LATITUDE': 38.904,
#     'LONGITUDE': -76.985,
#     'DATETIME': '2014-05-12T01:58:44.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9850000004, 38.9039999997]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1118,
#     'ID': '6D105284',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.886,
#     'LONGITUDE': -76.937,
#     'DATETIME': '2014-05-12T02:26:28.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9370000001, 38.8859999999]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1119,
#     'ID': '6D105286',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.889,
#     'LONGITUDE': -76.949,
#     'DATETIME': '2014-05-12T02:43:09.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9490000002, 38.8889999996]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1120,
#     'ID': '6D105288',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.884,
#     'LONGITUDE': -76.924,
#     'DATETIME': '2014-05-12T03:45:01.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9240000004, 38.8840000004]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1121,
#     'ID': '6D105289',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.884,
#     'LONGITUDE': -76.924,
#     'DATETIME': '2014-05-12T03:46:20.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9240000004, 38.8840000004]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1122,
#     'ID': '7D124910',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.848,
#     'LONGITUDE': -76.973,
#     'DATETIME': '2014-05-12T04:05:43.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9729999996, 38.8479999998]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1123,
#     'ID': '7D124915',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.837,
#     'LONGITUDE': -76.997,
#     'DATETIME': '2014-05-12T05:02:23.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9969999999, 38.8370000003]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1124,
#     'ID': '7D124918',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.844,
#     'LONGITUDE': -76.985,
#     'DATETIME': '2014-05-12T05:26:35.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9849999999, 38.8439999996]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1125,
#     'ID': '6D105294',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.873000000000005,
#     'LONGITUDE': -76.97200000000001,
#     'DATETIME': '2014-05-12T05:56:23.000Z'},
#    'geometry': {'type': 'Point', 'coordinates': [-76.972, 38.8729999998]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1126,
#     'ID': '6D105295',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.89,
#     'LONGITUDE': -76.932,
#     'DATETIME': '2014-05-12T06:04:37.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9320000001, 38.8900000003]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1127,
#     'ID': '6D105303',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.889,
#     'LONGITUDE': -76.953,
#     'DATETIME': '2014-05-12T15:19:41.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9529999997, 38.8890000001]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1128,
#     'ID': '6D105304',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.886,
#     'LONGITUDE': -76.947,
#     'DATETIME': '2014-05-12T17:21:46.000Z'},
#    'geometry': {'type': 'Point', 'coordinates': [-76.9469999997, 38.886]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1129,
#     'ID': '6D105305',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.889,
#     'LONGITUDE': -76.949,
#     'DATETIME': '2014-05-12T18:19:08.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9490000002, 38.8889999996]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1130,
#     'ID': '5D40763',
#     'TYPE': 'Gunshot_or_Firecracker',
#     'SOURCE': 'WashingtonDC5D',
#     'LATITUDE': 38.921,
#     'LONGITUDE': -76.979,
#     'DATETIME': '2014-05-12T23:33:30.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9790000006, 38.9210000004]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1131,
#     'ID': '7D125129',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.833,
#     'LONGITUDE': -77.007,
#     'DATETIME': '2014-05-13T00:58:46.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-77.0069999997, 38.8329999998]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1132,
#     'ID': '5D40769',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC5D',
#     'LATITUDE': 38.902,
#     'LONGITUDE': -76.977,
#     'DATETIME': '2014-05-13T02:10:11.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9770000002, 38.9019999996]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1133,
#     'ID': '6D105313',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.894,
#     'LONGITUDE': -76.924,
#     'DATETIME': '2014-05-13T02:37:27.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9239999999, 38.8939999997]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1134,
#     'ID': '7D125138',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.839,
#     'LONGITUDE': -76.99600000000001,
#     'DATETIME': '2014-05-13T03:07:42.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9960000003, 38.8389999996]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1135,
#     'ID': '6D105316',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.886,
#     'LONGITUDE': -76.95100000000001,
#     'DATETIME': '2014-05-13T03:22:42.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9510000004, 38.8859999998]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1136,
#     'ID': '6D105317',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.886,
#     'LONGITUDE': -76.95400000000001,
#     'DATETIME': '2014-05-13T03:22:48.000Z'},
#    'geometry': {'type': 'Point', 'coordinates': [-76.9539999995, 38.886]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1137,
#     'ID': '1D56608',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC1D',
#     'LATITUDE': 38.877,
#     'LONGITUDE': -77.018,
#     'DATETIME': '2014-01-29T23:53:22.000Z'},
#    'geometry': {'type': 'Point', 'coordinates': [-77.0179999995, 38.877]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1138,
#     'ID': '7D119859',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.835,
#     'LONGITUDE': -77.006,
#     'DATETIME': '2014-01-30T07:52:29.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-77.0059999999, 38.8349999996]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1139,
#     'ID': '6D102959',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.898,
#     'LONGITUDE': -76.949,
#     'DATETIME': '2014-01-30T12:53:56.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9489999998, 38.8980000002]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1140,
#     'ID': '7D119863',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.854,
#     'LONGITUDE': -76.97200000000001,
#     'DATETIME': '2014-01-31T02:53:02.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9719999996, 38.8540000001]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1141,
#     'ID': '1D56621',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC1D',
#     'LATITUDE': 38.877,
#     'LONGITUDE': -77.01700000000001,
#     'DATETIME': '2014-01-31T19:54:23.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-77.0169999997, 38.8770000004]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1142,
#     'ID': '7D119866',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.826,
#     'LONGITUDE': -76.99900000000001,
#     'DATETIME': '2014-02-01T02:44:21.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9990000003, 38.8259999996]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1143,
#     'ID': '6D102981',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.882000000000005,
#     'LONGITUDE': -76.924,
#     'DATETIME': '2014-02-01T04:28:41.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9239999996, 38.8819999999]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1144,
#     'ID': '6D102984',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.881,
#     'LONGITUDE': -76.938,
#     'DATETIME': '2014-02-01T05:28:43.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9380000001, 38.8810000001]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1145,
#     'ID': '7D119867',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.846000000000004,
#     'LONGITUDE': -76.983,
#     'DATETIME': '2014-02-01T05:34:11.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9830000004, 38.8460000003]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1146,
#     'ID': '6D102985',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.892,
#     'LONGITUDE': -76.952,
#     'DATETIME': '2014-02-01T08:06:01.000Z'},
#    'geometry': {'type': 'Point', 'coordinates': [-76.9519999998, 38.892]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1147,
#     'ID': '6D102986',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.892,
#     'LONGITUDE': -76.952,
#     'DATETIME': '2014-02-01T08:06:12.000Z'},
#    'geometry': {'type': 'Point', 'coordinates': [-76.9519999998, 38.892]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1148,
#     'ID': '6D102987',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.905,
#     'LONGITUDE': -76.914,
#     'DATETIME': '2014-02-01T08:34:19.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9139999996, 38.9049999997]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1149,
#     'ID': '7D119869',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.846000000000004,
#     'LONGITUDE': -76.971,
#     'DATETIME': '2014-02-01T16:44:11.000Z'},
#    'geometry': {'type': 'Point', 'coordinates': [-76.9710000005, 38.846]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1150,
#     'ID': '4D34595',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC4D',
#     'LATITUDE': 38.94,
#     'LONGITUDE': -77.024,
#     'DATETIME': '2014-02-01T20:08:16.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-77.0239999994, 38.9400000001]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1151,
#     'ID': '7D119870',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.821000000000005,
#     'LONGITUDE': -76.99900000000001,
#     'DATETIME': '2014-02-01T20:08:28.000Z'},
#    'geometry': {'type': 'Point', 'coordinates': [-76.999, 38.8210000001]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1152,
#     'ID': '1D56643',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC1D',
#     'LATITUDE': 38.892,
#     'LONGITUDE': -76.977,
#     'DATETIME': '2014-02-02T05:03:25.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9769999997, 38.8919999997]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1153,
#     'ID': '1D56644',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC1D',
#     'LATITUDE': 38.896,
#     'LONGITUDE': -76.983,
#     'DATETIME': '2014-02-02T05:06:33.000Z'},
#    'geometry': {'type': 'Point', 'coordinates': [-76.9829999995, 38.896]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1154,
#     'ID': '7D119876',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.827000000000005,
#     'LONGITUDE': -76.99900000000001,
#     'DATETIME': '2014-02-02T05:27:17.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9990000002, 38.8270000003]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1155,
#     'ID': '7D119877',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.845,
#     'LONGITUDE': -76.97800000000001,
#     'DATETIME': '2014-02-02T05:27:26.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9780000004, 38.8449999998]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1156,
#     'ID': '7D119878',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.847,
#     'LONGITUDE': -76.977,
#     'DATETIME': '2014-02-02T05:27:28.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9770000003, 38.8469999996]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1157,
#     'ID': '6D102999',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.896,
#     'LONGITUDE': -76.93,
#     'DATETIME': '2014-02-02T05:35:06.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9299999996, 38.8959999996]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1158,
#     'ID': '6D103000',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.896,
#     'LONGITUDE': -76.931,
#     'DATETIME': '2014-02-02T05:35:18.000Z'},
#    'geometry': {'type': 'Point', 'coordinates': [-76.9309999997, 38.896]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1159,
#     'ID': '6D103001',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.896,
#     'LONGITUDE': -76.931,
#     'DATETIME': '2014-02-02T05:35:19.000Z'},
#    'geometry': {'type': 'Point', 'coordinates': [-76.9309999997, 38.896]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1160,
#     'ID': '6D103002',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.884,
#     'LONGITUDE': -76.938,
#     'DATETIME': '2014-02-02T05:40:26.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9380000004, 38.8840000003]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1161,
#     'ID': '7D119879',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.836,
#     'LONGITUDE': -76.988,
#     'DATETIME': '2014-02-02T06:31:49.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9879999997, 38.8360000005]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1162,
#     'ID': '7D119880',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.845,
#     'LONGITUDE': -76.977,
#     'DATETIME': '2014-02-02T07:15:56.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9769999995, 38.8449999999]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1163,
#     'ID': '7D119881',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.838,
#     'LONGITUDE': -76.988,
#     'DATETIME': '2014-02-02T09:30:18.000Z'},
#    'geometry': {'type': 'Point', 'coordinates': [-76.988, 38.8380000003]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1164,
#     'ID': '5D39992',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC5D',
#     'LATITUDE': 38.909,
#     'LONGITUDE': -76.986,
#     'DATETIME': '2014-02-02T10:37:46.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9860000005, 38.9090000003]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1165,
#     'ID': '7D119884',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.844,
#     'LONGITUDE': -76.97800000000001,
#     'DATETIME': '2014-02-02T23:05:36.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9779999998, 38.8440000002]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1166,
#     'ID': '7D119887',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.861000000000004,
#     'LONGITUDE': -76.985,
#     'DATETIME': '2014-02-03T03:40:42.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9849999994, 38.8609999999]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1167,
#     'ID': '7D119888',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.862,
#     'LONGITUDE': -76.98100000000001,
#     'DATETIME': '2014-02-03T03:49:55.000Z'},
#    'geometry': {'type': 'Point', 'coordinates': [-76.9810000003, 38.862]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1168,
#     'ID': '6D103015',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.877,
#     'LONGITUDE': -76.932,
#     'DATETIME': '2014-02-03T05:00:47.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9320000003, 38.8770000004]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1169,
#     'ID': '7D119889',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.833,
#     'LONGITUDE': -77.006,
#     'DATETIME': '2014-02-03T06:09:12.000Z'},
#    'geometry': {'type': 'Point', 'coordinates': [-77.006, 38.8329999997]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1170,
#     'ID': '6D103018',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.88,
#     'LONGITUDE': -76.956,
#     'DATETIME': '2014-02-04T00:26:33.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9560000006, 38.8800000002]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1171,
#     'ID': '6D103021',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.893,
#     'LONGITUDE': -76.923,
#     'DATETIME': '2014-02-04T00:38:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9230000004, 38.8929999999]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1172,
#     'ID': '5D40001',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC5D',
#     'LATITUDE': 38.92,
#     'LONGITUDE': -76.983,
#     'DATETIME': '2014-02-04T02:31:45.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9829999998, 38.9200000004]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1173,
#     'ID': '6D103032',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.899,
#     'LONGITUDE': -76.917,
#     'DATETIME': '2014-02-04T17:25:24.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9170000004, 38.8990000004]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1174,
#     'ID': '7D119898',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.825,
#     'LONGITUDE': -77.00200000000001,
#     'DATETIME': '2014-02-04T21:03:54.000Z'},
#    'geometry': {'type': 'Point', 'coordinates': [-77.002, 38.8250000002]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1175,
#     'ID': '6D103037',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.905,
#     'LONGITUDE': -76.92,
#     'DATETIME': '2014-02-04T22:46:27.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9199999997, 38.9050000002]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1176,
#     'ID': '6D103038',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.911,
#     'LONGITUDE': -76.929,
#     'DATETIME': '2014-02-04T22:52:25.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9290000004, 38.9110000001]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1177,
#     'ID': '4D34615',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC4D',
#     'LATITUDE': 38.953,
#     'LONGITUDE': -77.031,
#     'DATETIME': '2014-02-05T00:13:17.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-77.0310000003, 38.9530000005]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1178,
#     'ID': '6D103044',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.883,
#     'LONGITUDE': -76.938,
#     'DATETIME': '2014-02-05T03:28:39.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9380000003, 38.8829999998]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1179,
#     'ID': '7D119901',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.836,
#     'LONGITUDE': -76.99600000000001,
#     'DATETIME': '2014-02-05T08:03:52.000Z'},
#    'geometry': {'type': 'Point', 'coordinates': [-76.9960000001, 38.836]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1180,
#     'ID': '5D40014',
#     'TYPE': 'Gunshot_or_Firecracker',
#     'SOURCE': 'WashingtonDC5D',
#     'LATITUDE': 38.922000000000004,
#     'LONGITUDE': -76.985,
#     'DATETIME': '2014-02-05T08:30:59.000Z'},
#    'geometry': {'type': 'Point', 'coordinates': [-76.9849999995, 38.922]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1181,
#     'ID': '5D40020',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC5D',
#     'LATITUDE': 38.908,
#     'LONGITUDE': -76.99,
#     'DATETIME': '2014-02-06T00:02:07.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9899999999, 38.9079999999]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1182,
#     'ID': '1D56664',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC1D',
#     'LATITUDE': 38.891000000000005,
#     'LONGITUDE': -76.983,
#     'DATETIME': '2014-02-06T00:17:44.000Z'},
#    'geometry': {'type': 'Point', 'coordinates': [-76.983, 38.8910000001]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1183,
#     'ID': '6D103056',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.887,
#     'LONGITUDE': -76.934,
#     'DATETIME': '2014-02-06T00:24:13.000Z'},
#    'geometry': {'type': 'Point', 'coordinates': [-76.934, 38.8869999999]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1184,
#     'ID': '1D56668',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC1D',
#     'LATITUDE': 38.876000000000005,
#     'LONGITUDE': -77.016,
#     'DATETIME': '2014-02-06T01:01:15.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-77.0160000003, 38.8759999996]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1185,
#     'ID': '5D40031',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC5D',
#     'LATITUDE': 38.911,
#     'LONGITUDE': -76.994,
#     'DATETIME': '2014-02-07T01:41:28.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9940000004, 38.9110000003]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1186,
#     'ID': '7D119918',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.851,
#     'LONGITUDE': -76.986,
#     'DATETIME': '2014-02-07T07:02:57.000Z'},
#    'geometry': {'type': 'Point', 'coordinates': [-76.986, 38.8509999998]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1187,
#     'ID': '7D119922',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.828,
#     'LONGITUDE': -77.001,
#     'DATETIME': '2014-02-07T18:00:07.000Z'},
#    'geometry': {'type': 'Point', 'coordinates': [-77.001, 38.8279999999]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1188,
#     'ID': '7D119927',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.861000000000004,
#     'LONGITUDE': -76.99300000000001,
#     'DATETIME': '2014-02-07T21:57:04.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9929999998, 38.8610000004]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1189,
#     'ID': '4D34625',
#     'TYPE': 'Gunshot_or_Firecracker',
#     'SOURCE': 'WashingtonDC4D',
#     'LATITUDE': 38.952000000000005,
#     'LONGITUDE': -77.025,
#     'DATETIME': '2014-02-08T02:38:57.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-77.0249999998, 38.9519999996]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1190,
#     'ID': '1D56680',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC1D',
#     'LATITUDE': 38.899,
#     'LONGITUDE': -76.973,
#     'DATETIME': '2014-02-08T03:20:13.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9729999994, 38.8990000004]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1191,
#     'ID': '6D103094',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.888000000000005,
#     'LONGITUDE': -76.931,
#     'DATETIME': '2014-02-08T03:49:16.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9309999999, 38.8880000003]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1192,
#     'ID': '6D103095',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.889,
#     'LONGITUDE': -76.92,
#     'DATETIME': '2014-02-08T05:16:05.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9200000004, 38.8889999999]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1193,
#     'ID': '6D103097',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.882000000000005,
#     'LONGITUDE': -76.935,
#     'DATETIME': '2014-02-08T06:10:11.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9349999995, 38.8820000004]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1194,
#     'ID': '6D103098',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.882000000000005,
#     'LONGITUDE': -76.936,
#     'DATETIME': '2014-02-08T06:10:23.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9360000005, 38.8819999996]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1195,
#     'ID': '6D103099',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.882000000000005,
#     'LONGITUDE': -76.935,
#     'DATETIME': '2014-02-08T06:10:34.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9349999995, 38.8820000004]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1196,
#     'ID': '6D103101',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.884,
#     'LONGITUDE': -76.955,
#     'DATETIME': '2014-02-08T07:33:15.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9550000004, 38.8840000002]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1197,
#     'ID': '7D119930',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.84,
#     'LONGITUDE': -76.98700000000001,
#     'DATETIME': '2014-02-08T07:36:47.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9870000003, 38.8399999997]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1198,
#     'ID': '7D119931',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.846000000000004,
#     'LONGITUDE': -77.001,
#     'DATETIME': '2014-02-08T07:55:50.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-77.0010000004, 38.8460000003]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1199,
#     'ID': '7D119932',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.838,
#     'LONGITUDE': -77.003,
#     'DATETIME': '2014-02-08T08:12:10.000Z'},
#    'geometry': {'type': 'Point', 'coordinates': [-77.0030000001, 38.838]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1200,
#     'ID': '7D119933',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.838,
#     'LONGITUDE': -76.988,
#     'DATETIME': '2014-02-08T08:18:45.000Z'},
#    'geometry': {'type': 'Point', 'coordinates': [-76.988, 38.8380000003]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1201,
#     'ID': '4D34626',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC4D',
#     'LATITUDE': 38.944,
#     'LONGITUDE': -77.013,
#     'DATETIME': '2014-02-08T08:36:51.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-77.0130000005, 38.9439999996]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1202,
#     'ID': '6D103109',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.893,
#     'LONGITUDE': -76.915,
#     'DATETIME': '2014-02-08T18:08:36.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9150000004, 38.8930000001]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1203,
#     'ID': '6D103110',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.898,
#     'LONGITUDE': -76.921,
#     'DATETIME': '2014-02-08T19:22:01.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9209999998, 38.8980000003]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1204,
#     'ID': '5D40047',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC5D',
#     'LATITUDE': 38.913000000000004,
#     'LONGITUDE': -76.986,
#     'DATETIME': '2014-02-09T06:35:16.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9859999995, 38.9129999998]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1205,
#     'ID': '6D103113',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.883,
#     'LONGITUDE': -76.94,
#     'DATETIME': '2014-02-09T06:38:09.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9400000003, 38.8830000003]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1206,
#     'ID': '6D103114',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.901,
#     'LONGITUDE': -76.926,
#     'DATETIME': '2014-02-09T06:54:35.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9259999999, 38.9009999996]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1207,
#     'ID': '7D119941',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.827000000000005,
#     'LONGITUDE': -77.007,
#     'DATETIME': '2014-02-09T07:45:26.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-77.0069999999, 38.8269999999]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1208,
#     'ID': '7D119942',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.855000000000004,
#     'LONGITUDE': -76.991,
#     'DATETIME': '2014-02-09T07:58:09.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9909999997, 38.8549999997]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1209,
#     'ID': '5D40048',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC5D',
#     'LATITUDE': 38.906,
#     'LONGITUDE': -77.01100000000001,
#     'DATETIME': '2014-02-09T08:11:33.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-77.0110000004, 38.9060000004]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1210,
# ...
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.845,
#     'LONGITUDE': -76.98400000000001,
#     'DATETIME': '2014-06-27T02:12:25.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9839999998, 38.8449999998]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1849,
#     'ID': '7D141130',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.848,
#     'LONGITUDE': -76.971,
#     'DATETIME': '2014-06-27T02:28:50.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9710000002, 38.8480000003]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1850,
#     'ID': '7D141131',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.848,
#     'LONGITUDE': -76.971,
#     'DATETIME': '2014-06-27T02:29:05.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9710000002, 38.8480000003]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1851,
#     'ID': '7D141133',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.827000000000005,
#     'LONGITUDE': -76.99900000000001,
#     'DATETIME': '2014-06-27T02:31:40.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9990000002, 38.8270000003]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1852,
#     'ID': '6D108459',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.872,
#     'LONGITUDE': -76.967,
#     'DATETIME': '2014-06-27T02:56:50.000Z'},
#    'geometry': {'type': 'Point', 'coordinates': [-76.967, 38.8719999998]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1853,
#     'ID': '5D42117',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC5D',
#     'LATITUDE': 38.902,
#     'LONGITUDE': -76.995,
#     'DATETIME': '2014-06-27T02:58:54.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9949999996, 38.9019999997]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1854,
#     'ID': '7D141154',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.848,
#     'LONGITUDE': -76.97,
#     'DATETIME': '2014-06-27T03:13:21.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9699999999, 38.8479999999]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1855,
#     'ID': '7D141155',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.848,
#     'LONGITUDE': -76.97,
#     'DATETIME': '2014-06-27T03:13:25.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9699999999, 38.8479999999]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1856,
#     'ID': '7D141156',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.848,
#     'LONGITUDE': -76.97,
#     'DATETIME': '2014-06-27T03:13:26.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9699999999, 38.8479999999]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1857,
#     'ID': '7D141157',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.848,
#     'LONGITUDE': -76.97,
#     'DATETIME': '2014-06-27T03:13:35.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9699999999, 38.8479999999]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1858,
#     'ID': '7D141159',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.844,
#     'LONGITUDE': -76.98700000000001,
#     'DATETIME': '2014-06-27T03:13:56.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9870000001, 38.8439999998]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1859,
#     'ID': '5D42121',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC5D',
#     'LATITUDE': 38.922000000000004,
#     'LONGITUDE': -76.99,
#     'DATETIME': '2014-06-27T03:28:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9899999998, 38.9219999997]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1860,
#     'ID': '6D108473',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.9,
#     'LONGITUDE': -76.94,
#     'DATETIME': '2014-06-27T03:45:27.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9400000004, 38.8999999999]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1861,
#     'ID': '6D108475',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.887,
#     'LONGITUDE': -76.917,
#     'DATETIME': '2014-06-27T03:47:12.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9170000006, 38.8869999996]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1862,
#     'ID': '7D141163',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.827000000000005,
#     'LONGITUDE': -77.00800000000001,
#     'DATETIME': '2014-06-27T03:48:38.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-77.0079999997, 38.8270000004]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1863,
#     'ID': '4D35555',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC4D',
#     'LATITUDE': 38.956,
#     'LONGITUDE': -77.022,
#     'DATETIME': '2014-06-27T04:17:35.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-77.0220000005, 38.9559999996]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1864,
#     'ID': '6D108479',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.877,
#     'LONGITUDE': -76.927,
#     'DATETIME': '2014-06-27T04:20:55.000Z'},
#    'geometry': {'type': 'Point', 'coordinates': [-76.9269999997, 38.877]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1865,
#     'ID': '6D108481',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.899,
#     'LONGITUDE': -76.943,
#     'DATETIME': '2014-06-27T04:50:27.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9429999995, 38.8990000001]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1866,
#     'ID': '4D35557',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC4D',
#     'LATITUDE': 38.947,
#     'LONGITUDE': -77.021,
#     'DATETIME': '2014-06-27T04:52:22.000Z'},
#    'geometry': {'type': 'Point', 'coordinates': [-77.0210000004, 38.947]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1867,
#     'ID': '6D108485',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.911,
#     'LONGITUDE': -76.937,
#     'DATETIME': '2014-06-27T04:53:08.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9369999994, 38.9110000003]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1868,
#     'ID': '6D108490',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.894,
#     'LONGITUDE': -76.923,
#     'DATETIME': '2014-06-27T07:07:28.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9230000001, 38.8939999997]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1869,
#     'ID': '6D108491',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.874,
#     'LONGITUDE': -76.97800000000001,
#     'DATETIME': '2014-06-27T07:25:54.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9779999999, 38.8739999998]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1870,
#     'ID': '7D141187',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.87,
#     'LONGITUDE': -76.994,
#     'DATETIME': '2014-06-27T14:03:39.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9939999997, 38.8699999998]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1871,
#     'ID': '7D141189',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.87,
#     'LONGITUDE': -76.994,
#     'DATETIME': '2014-06-27T14:03:49.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9939999997, 38.8699999998]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1872,
#     'ID': '7D141192',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.87,
#     'LONGITUDE': -76.994,
#     'DATETIME': '2014-06-27T14:04:14.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9939999997, 38.8699999998]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1873,
#     'ID': '7D141207',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.848,
#     'LONGITUDE': -76.97,
#     'DATETIME': '2014-06-27T16:01:08.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9699999999, 38.8479999999]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1874,
#     'ID': '7D141210',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.848,
#     'LONGITUDE': -76.971,
#     'DATETIME': '2014-06-27T16:01:32.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9710000002, 38.8480000003]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1875,
#     'ID': '7D141217',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.832,
#     'LONGITUDE': -77.006,
#     'DATETIME': '2014-06-27T19:06:07.000Z'},
#    'geometry': {'type': 'Point', 'coordinates': [-77.006, 38.8319999999]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1876,
#     'ID': '7D141241',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.849000000000004,
#     'LONGITUDE': -76.971,
#     'DATETIME': '2014-06-27T20:46:12.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9709999995, 38.8490000002]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1877,
#     'ID': '6D108505',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.887,
#     'LONGITUDE': -76.94800000000001,
#     'DATETIME': '2014-06-27T22:18:55.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9479999998, 38.8869999999]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1878,
#     'ID': '6D108506',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.887,
#     'LONGITUDE': -76.95100000000001,
#     'DATETIME': '2014-06-27T22:26:25.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9509999995, 38.8869999997]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1879,
#     'ID': '1D58678',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC1D',
#     'LATITUDE': 38.896,
#     'LONGITUDE': -76.97800000000001,
#     'DATETIME': '2014-06-27T23:14:44.000Z'},
#    'geometry': {'type': 'Point', 'coordinates': [-76.978, 38.8959999996]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1880,
#     'ID': '7D141307',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.841,
#     'LONGITUDE': -76.989,
#     'DATETIME': '2014-06-27T23:50:29.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9890000005, 38.8410000001]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1881,
#     'ID': '7D141309',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.841,
#     'LONGITUDE': -76.989,
#     'DATETIME': '2014-06-27T23:50:33.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9890000005, 38.8410000001]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1882,
#     'ID': '7D141325',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.849000000000004,
#     'LONGITUDE': -76.97500000000001,
#     'DATETIME': '2014-06-28T00:07:31.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9750000002, 38.8490000001]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1883,
#     'ID': '6D108526',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.883,
#     'LONGITUDE': -76.96000000000001,
#     'DATETIME': '2014-06-28T00:29:10.000Z'},
#    'geometry': {'type': 'Point', 'coordinates': [-76.96, 38.8830000003]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1884,
#     'ID': '7D141356',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.856,
#     'LONGITUDE': -76.973,
#     'DATETIME': '2014-06-28T00:47:12.000Z'},
#    'geometry': {'type': 'Point', 'coordinates': [-76.9730000003, 38.856]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1885,
#     'ID': '7D141369',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.827000000000005,
#     'LONGITUDE': -76.99900000000001,
#     'DATETIME': '2014-06-28T00:59:24.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9990000002, 38.8270000003]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1886,
#     'ID': '6D108537',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.894,
#     'LONGITUDE': -76.913,
#     'DATETIME': '2014-06-28T01:06:28.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9129999999, 38.8940000004]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1887,
#     'ID': '7D141392',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.827000000000005,
#     'LONGITUDE': -77,
#     'DATETIME': '2014-06-28T01:24:01.000Z'},
#    'geometry': {'type': 'Point', 'coordinates': [-77, 38.827]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1888,
#     'ID': '7D141400',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.856,
#     'LONGITUDE': -76.974,
#     'DATETIME': '2014-06-28T01:28:05.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9739999998, 38.8559999999]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1889,
#     'ID': '7D141406',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.847,
#     'LONGITUDE': -76.974,
#     'DATETIME': '2014-06-28T01:29:39.000Z'},
#    'geometry': {'type': 'Point', 'coordinates': [-76.974, 38.8469999997]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1890,
#     'ID': '7D141414',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.848,
#     'LONGITUDE': -76.974,
#     'DATETIME': '2014-06-28T01:33:54.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9739999999, 38.8479999998]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1891,
#     'ID': '7D141429',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.847,
#     'LONGITUDE': -76.974,
#     'DATETIME': '2014-06-28T01:42:26.000Z'},
#    'geometry': {'type': 'Point', 'coordinates': [-76.974, 38.8469999997]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1892,
#     'ID': '7D141438',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.847,
#     'LONGITUDE': -76.973,
#     'DATETIME': '2014-06-28T01:43:14.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9729999999, 38.8469999998]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1893,
#     'ID': '6D108597',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.901,
#     'LONGITUDE': -76.936,
#     'DATETIME': '2014-06-28T01:49:09.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9360000003, 38.9009999997]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1894,
#     'ID': '7D141471',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.847,
#     'LONGITUDE': -76.974,
#     'DATETIME': '2014-06-28T02:25:07.000Z'},
#    'geometry': {'type': 'Point', 'coordinates': [-76.974, 38.8469999997]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1895,
#     'ID': '7D141473',
#     'TYPE': 'Multiple_Gunshots',
#     'SOURCE': 'WashingtonDC7D',
#     'LATITUDE': 38.848,
#     'LONGITUDE': -76.974,
#     'DATETIME': '2014-06-28T02:25:24.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9739999999, 38.8479999998]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1896,
#     'ID': '6D108611',
#     'TYPE': 'Single_Gunshot',
#     'SOURCE': 'WashingtonDC6D',
#     'LATITUDE': 38.885000000000005,
#     'LONGITUDE': -76.95700000000001,
#     'DATETIME': '2014-06-28T02:26:15.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.9569999996, 38.8849999998]}},
#   ...]}

# %%
response.json().keys()
# Out:
# dict_keys(['type', 'features'])

# %%
from pandas.io.json import json_normalize

# %%
df = pd.DataFrame.from_dict(json_normalize(response.json()['features']))

# %%
df.columns = [X.replace('properties.', '') for X in df.columns]

# %%
df.columns = [X.replace('geometry.', '') for X in df.columns]

# %%
import cufflinks as cf

# %%
df.tail()
# Out:
#                            coordinates   type                  DATETIME  \
# 32975  [-77.0159999994, 38.9190000003]  Point  2018-12-02T06:22:56.000Z
# 32976         [-76.9359999995, 38.913]  Point  2018-12-02T07:52:48.000Z
# 32977         [-77.001, 38.8279999999]  Point  2018-12-02T08:46:31.000Z
# 32978  [-76.9680000001, 38.8509999996]  Point  2018-12-02T08:56:21.000Z
# 32979  [-76.9439999997, 38.8919999998]  Point  2018-12-02T09:26:31.000Z
#
#              ID  LATITUDE  LONGITUDE  OBJECTID          SOURCE  \
# 32975   3D76962    38.919    -77.016     32370  WashingtonDC3D
# 32976  6D232666    38.913    -76.936     32371  WashingtonDC6D
# 32977  7D301678    38.828    -77.001     32372  WashingtonDC7D
# 32978  7D301679    38.851    -76.968     32373  WashingtonDC7D
# 32979  6D232667    38.892    -76.944     32374  WashingtonDC6D
#
#                          TYPE     type
# 32975       Multiple_Gunshots  Feature
# 32976       Multiple_Gunshots  Feature
# 32977          Single_Gunshot  Feature
# 32978          Single_Gunshot  Feature
# 32979  Gunshot_or_Firecracker  Feature

# %% [markdown]
# ## Briefly Explore the Structure of the Response You Received.

# %% [markdown]
# ### Let's look at the output of our API call to NYC 311

# %%
print(type(data))
# Out:
# <class 'list'>

# %%
len(data)
# Out:
# 1000

# %%
data[0]
# Out:
# {'address_type': 'ADDRESS',
#  'agency': 'NYPD',
#  'agency_name': 'New York City Police Department',
#  'bbl': '4084460001',
#  'borough': 'QUEENS',
#  'city': 'GLEN OAKS',
#  'closed_date': '2019-05-14T00:45:22.000',
#  'community_board': '13 QUEENS',
#  'complaint_type': 'Noise - Residential',
#  'created_date': '2019-05-13T23:06:30.000',
#  'cross_street_1': '73 AVENUE',
#  'cross_street_2': 'BEND',
#  'descriptor': 'Banging/Pounding',
#  'due_date': '2019-05-14T07:06:30.000',
#  'facility_type': 'Precinct',
#  'incident_address': '73-01 260 STREET',
#  'incident_zip': '11004',
#  'latitude': '40.75076013157645',
#  'location': {'type': 'Point',
#   'coordinates': [-73.717529079357, 40.750760131576]},
#  'location_type': 'Residential Building/House',
#  'longitude': '-73.7175290793568',
#  'open_data_channel_type': 'ONLINE',
#  'park_borough': 'QUEENS',
#  'park_facility_name': 'Unspecified',
#  'resolution_action_updated_date': '2019-05-14T00:45:22.000',
#  'resolution_description': 'The Police Department responded to the complaint and with the information available observed no evidence of the violation at that time.',
#  'status': 'Closed',
#  'street_name': '260 STREET',
#  'unique_key': '42663284',
#  'x_coordinate_state_plane': '1062514',
#  'y_coordinate_state_plane': '212925'}

# %% [markdown]
# ### Libraries for company-specific APIs
#
# Google has its own libraries you can import to access their apis. <br>
# NYC also uses the `sodapy` library, Socrata, to manage their open data.

# %% [markdown]
# #### Extra credit for later if you want to play with it

# %%
# Install before running 
# !pip install sodapy
# Out:
# Collecting sodapy
#   Downloading https://files.pythonhosted.org/packages/11/02/5baf6e10a47018babcc43e3ed03a6f13712187f4ab1fbe263b479c77d117/sodapy-1.5.2-py2.py3-none-any.whl
# Requirement already satisfied: future>=0.17.1 in /anaconda3/lib/python3.7/site-packages (from sodapy) (0.17.1)
# Requirement already satisfied: requests>=2.20.0 in /anaconda3/lib/python3.7/site-packages (from sodapy) (2.21.0)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /anaconda3/lib/python3.7/site-packages (from requests>=2.20.0->sodapy) (1.24.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /anaconda3/lib/python3.7/site-packages (from requests>=2.20.0->sodapy) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /anaconda3/lib/python3.7/site-packages (from requests>=2.20.0->sodapy) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda3/lib/python3.7/site-packages (from requests>=2.20.0->sodapy) (2019.3.9)
# Installing collected packages: sodapy
# Successfully installed sodapy-1.5.2

# %% [markdown]
# #### Tokenize yourself, B!
#
# https://dev.socrata.com/foundry/data.cityofnewyork.us/fhrw-4uyv
#
# Scroll down and click to sign up for an app token! This is instantaneous and simple. No credit cards required!

# %%
token = '' 

import pandas as pd
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofnewyork.us", token)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.cityofnewyork.us,
#                  MyAppToken,
#                  userame="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("fhrw-4uyv", incident_zip = '11004', limit=1000)

# %%
type(results)
# Out:
# requests.models.Response

# %%
len(results)

# %%
results[0]

# %%
df_1 = pd.DataFrame(results)

print(len(df_1))
print(df_1.columns)
df_1.head()

# %% [markdown]
# ## Create a Pandas DataFrame of the Data From the Response

# %%
df_2 = pd.DataFrame(data)

print(len(df_2))
print(df_2.columns)
df_2.head()

# %% [markdown]
# ## Create a Histogram of the Complaint Types From Your Dataset

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_2.complaint_type.value_counts().plot(kind='barh', figsize=(8,12))

# %% [markdown]
# ## If we have time:
#
# https://github.com/toddmotto/public-apis
#
#
# find a buddy, find a free api, get the key, and do a get. Try to transform the response into a df.
